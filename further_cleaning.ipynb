# %%
import pandas as pd

# %%
# read csv dated June 2017
csv1 = "Output/all_combined.csv"
winter_summer = pd.read_csv(csv1)
winter_summer
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 499       2017-06-01 00:01:39       2017-06-01 00:09:59
# 1                 507       2017-06-01 00:06:39       2017-06-01 00:15:07
# 2                 768       2017-06-01 00:44:43       2017-06-01 00:57:31
# 3                 101       2017-06-01 01:12:55       2017-06-01 01:14:36
# 4                 265       2017-06-01 01:14:00       2017-06-01 01:18:25
# ...               ...                       ...                       ...
# 8331764           367  2019-02-21 12:05:05.2680  2019-02-21 12:11:13.2210
# 8331765           497  2019-02-21 17:45:00.4510  2019-02-21 17:53:18.1580
# 8331766           959  2019-02-25 06:17:31.9310  2019-02-25 06:33:31.4950
# 8331767           936  2019-02-26 06:14:45.4170  2019-02-26 06:30:21.8750
# 8331768           822  2019-02-26 15:45:20.5370  2019-02-26 15:59:02.6070
#
#          start station id start station name  start station latitude  \
# ...

# %%
winter_summer['age'] = 2020 - winter_summer['birth year']
winter_summer
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 499       2017-06-01 00:01:39       2017-06-01 00:09:59
# 1                 507       2017-06-01 00:06:39       2017-06-01 00:15:07
# 2                 768       2017-06-01 00:44:43       2017-06-01 00:57:31
# 3                 101       2017-06-01 01:12:55       2017-06-01 01:14:36
# 4                 265       2017-06-01 01:14:00       2017-06-01 01:18:25
# ...               ...                       ...                       ...
# 8331764           367  2019-02-21 12:05:05.2680  2019-02-21 12:11:13.2210
# 8331765           497  2019-02-21 17:45:00.4510  2019-02-21 17:53:18.1580
# 8331766           959  2019-02-25 06:17:31.9310  2019-02-25 06:33:31.4950
# 8331767           936  2019-02-26 06:14:45.4170  2019-02-26 06:30:21.8750
# 8331768           822  2019-02-26 15:45:20.5370  2019-02-26 15:59:02.6070
#
#          start station id start station name  start station latitude  \
# ...

# %%
# code source: https://www.geeksforgeeks.org/how-to-drop-one-or-multiple-columns-in-pandas-dataframe/
winter_summer = winter_summer.drop(['start station id',  
                                            'end station id', 
                                           'end station name'], axis = 1)

# %%
winter_summer['tripduration_mins'] = winter_summer['tripduration'] / 60
# winter_summer_chopped

# %%
winter_summer['tripduration_hrs'] = winter_summer['tripduration_mins'] / 60

# %%
winter_summer
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 499       2017-06-01 00:01:39       2017-06-01 00:09:59
# 1                 507       2017-06-01 00:06:39       2017-06-01 00:15:07
# 2                 768       2017-06-01 00:44:43       2017-06-01 00:57:31
# 3                 101       2017-06-01 01:12:55       2017-06-01 01:14:36
# 4                 265       2017-06-01 01:14:00       2017-06-01 01:18:25
# ...               ...                       ...                       ...
# 8331764           367  2019-02-21 12:05:05.2680  2019-02-21 12:11:13.2210
# 8331765           497  2019-02-21 17:45:00.4510  2019-02-21 17:53:18.1580
# 8331766           959  2019-02-25 06:17:31.9310  2019-02-25 06:33:31.4950
# 8331767           936  2019-02-26 06:14:45.4170  2019-02-26 06:30:21.8750
# 8331768           822  2019-02-26 15:45:20.5370  2019-02-26 15:59:02.6070
#
#         start station name  start station latitude  start station longitude  \
# ...

# %%
winter_summer = winter_summer.drop(['stoptime'], axis = 1)

# %%
winter_summer
# Out:
#          tripduration                 starttime start station name  \
# 0                 499       2017-06-01 00:01:39            Sip Ave
# 1                 507       2017-06-01 00:06:39         Newark Ave
# 2                 768       2017-06-01 00:44:43            Sip Ave
# 3                 101       2017-06-01 01:12:55          City Hall
# 4                 265       2017-06-01 01:14:00       Manila & 1st
# ...               ...                       ...                ...
# 8331764           367  2019-02-21 12:05:05.2680     Jackson Square
# 8331765           497  2019-02-21 17:45:00.4510     Jackson Square
# 8331766           959  2019-02-25 06:17:31.9310     Jackson Square
# 8331767           936  2019-02-26 06:14:45.4170     Jackson Square
# 8331768           822  2019-02-26 15:45:20.5370     Jackson Square
#
#          start station latitude  start station longitude  \
# 0                     40.730743               -74.063784
# ...

# %%
winter_summer.dropna(subset=['usertype'])
# Out:
#          tripduration                 starttime start station name  \
# 0                 499       2017-06-01 00:01:39            Sip Ave
# 1                 507       2017-06-01 00:06:39         Newark Ave
# 2                 768       2017-06-01 00:44:43            Sip Ave
# 3                 101       2017-06-01 01:12:55          City Hall
# 4                 265       2017-06-01 01:14:00       Manila & 1st
# ...               ...                       ...                ...
# 8331764           367  2019-02-21 12:05:05.2680     Jackson Square
# 8331765           497  2019-02-21 17:45:00.4510     Jackson Square
# 8331766           959  2019-02-25 06:17:31.9310     Jackson Square
# 8331767           936  2019-02-26 06:14:45.4170     Jackson Square
# 8331768           822  2019-02-26 15:45:20.5370     Jackson Square
#
#          start station latitude  start station longitude  \
# 0                     40.730743               -74.063784
# ...

# %%
# First filter out those rows which 
# does not contain any data 
winter_summer = winter_summer.dropna(how = 'all') 
  
# Filter all rows for which the player's 
# age is greater than or equal to 25 
winter_summer.drop(winter_summer[winter_summer['age'] > 101].index, inplace = True) 
  
# # Print the modified dataframe 
# print(winter_summer.head(15)) 
  
# # Print the shape of the dataframe 
# print(winter_summer.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-70fb261e9828> in <module>
#       5 # Filter all rows for which the player's
#       6 # age is greater than or equal to 25
# ----> 7 winter_summer.drop(winter_summer[winter_summer['age'] > 101].index, inplace = True)
#       8
#       9 # # Print the modified dataframe
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# ...

# %%
winter_summer.head(2)
# Out:
#    tripduration            starttime start station name  \
# 0           499  2017-06-01 00:01:39            Sip Ave
# 1           507  2017-06-01 00:06:39         Newark Ave
#
#    start station latitude  start station longitude  end station latitude  \
# 0               40.730743               -74.063784             40.725340
# 1               40.721525               -74.046305             40.714358
#
#    end station longitude  bikeid    usertype  birth year  gender   age  \
# 0             -74.067622   29590  Subscriber      1979.0       1  41.0
# 1             -74.066611   29453  Subscriber      1969.0       1  51.0
#
#    tripduration_mins  tripduration_hrs
# 0           8.316667          0.138611
# 1           8.450000          0.140833

# %%
winter_summer['age'].max()
# Out:
# 101.0

# %%
winter_summer.to_csv('Output/age_w_s_condensed.csv', index=False)
